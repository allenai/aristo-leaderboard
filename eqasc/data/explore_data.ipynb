# %%
import json
import numpy
import random

# %%
DATA_DIR='eqasc/'
SUFFIX = '_grc.json'

# %%
split = 'dev'

# %%
def load_data(fname):
    data = [ ]
    data = json.load(open(fname, 'r'))
    return data

# %%
fname = DATA_DIR + 'eqasc_' + split + SUFFIX

data = load_data(fname)
print("len(data) = ", len(data))
# Out:
# len(data) =  926

# %%
###############

# %%
random.seed(123)

# %%
def show_random_example(data, show_correct_choice_only=True):
    
    row = random.choice(data)
    df_correct_choice = None
    correct_choice = row[ 'answerKey' ]
    ques = row['question']['stem'].lower().strip()
    #print("==== correct_choice = ", correct_choice)
    print("==== ques = ", ques)
    
    for c in row[ 'question' ][ 'choices' ]: # each question has 8 choices typically

        option = c[ "text" ]
        option = option.lower().strip()
        df = c['df']
        if correct_choice == c['label']:
            option_correct_choice = option
        else:
            if show_correct_choice_only:
                continue
        print("-"*44)
        #print("==== row['answerKey'] = ", correct_choice)
        print("==== option = ", option)
        #print("==== df = ", df)
        
        for j,chain in enumerate(c['chains']):
            
            print("="*24)
            f1, f2 = chain[ 0 ][ 'text' ], chain[ 1 ][ 'text' ]
            chain2 = chain[2]
            overlapping_entities = chain2['overlapping_entities'] 
            print("f1= ", f1 )
            print("f2= ", f2 )
            print("df= ", df )
            # we consider reasoning chain as (f1,f2,df)
            #print("[overlapping_entities]: txt12_candidates= ", overlapping_entities['txt12_candidates'] )
            #print("[overlapping_entities]: txt1c_candidates= ", overlapping_entities['txt1c_candidates'] )
            #print("[overlapping_entities]: txt2c_candidates= ", overlapping_entities['txt2c_candidates'] )
            print(" ---->>> j=", j, "chain = ", json.dumps(c[ 'chains' ][ j ], indent=4))
            # 'score' field holds retrieval score
            # 'df' is declaritive form of question+answer
            # 'grc' (generalized reasoning chain) is obtained after variablizing (f1,f2,df)

# %%
show_random_example(data, show_correct_choice_only=True)
# Out:
# ==== ques =  what can be used to find your way if you're lost in the dark?
# --------------------------------------------
# ==== option =  the north star
# ========================
# f1=  Art can find the lost Art can find the lost Art can find the lost.
# f2=  North Star clip art was created by Peter Reynolds, author and illustrator of The North Star.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 0 chain =  [
#     {
#         "text": "Art can find the lost Art can find the lost Art can find the lost.",
#         "score": 20.327402
#     },
#     {
#         "text": "North Star clip art was created by Peter Reynolds, author and illustrator of The North Star.",
#         "score": 29.083858
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "art"
#                 ],
#                 "txt2_candidates": [
#                     "art"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "lost"
#                 ],
#                 "txtc_candidates": [
#                     "lost"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "the north star"
#                 ],
#                 "txtc_candidates": [
#                     "the north star"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_1",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             " [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3] ",
#             "north star clip  [unused1]  was created by peter reynolds author and illustrator of  [unused5] ",
#             " [unused5]  can be used to find your way if you  re  [unused3]  in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Art can find the lost Art can find the lost Art can find the lost.
# f2=  Star Art Stars in the sky are beautiful.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 1 chain =  [
#     {
#         "text": "Art can find the lost Art can find the lost Art can find the lost.",
#         "score": 20.327402
#     },
#     {
#         "text": "Star Art Stars in the sky are beautiful.",
#         "score": 28.853397
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "art"
#                 ],
#                 "txt2_candidates": [
#                     "art"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "lost"
#                 ],
#                 "txtc_candidates": [
#                     "lost"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "stars"
#                 ],
#                 "txtc_candidates": [
#                     "star"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_2",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             " [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3] ",
#             " [unused4]   [unused1]   [unused4]  in the sky are beautiful",
#             "the north  [unused4]  can be used to find your way if you  re  [unused3]  in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Art can find the lost Art can find the lost Art can find the lost.
# f2=  Star Art Star Art Star watching has occupied humans from the earliest times.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 2 chain =  [
#     {
#         "text": "Art can find the lost Art can find the lost Art can find the lost.",
#         "score": 20.327402
#     },
#     {
#         "text": "Star Art Star Art Star watching has occupied humans from the earliest times.",
#         "score": 28.424355
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "art"
#                 ],
#                 "txt2_candidates": [
#                     "art"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "lost"
#                 ],
#                 "txtc_candidates": [
#                     "lost"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "star"
#                 ],
#                 "txtc_candidates": [
#                     "star"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_3",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             " [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3] ",
#             " [unused5]   [unused1]   [unused5]   [unused1]   [unused5]  watching has occupied humans from the earliest times",
#             "the north  [unused5]  can be used to find your way if you  re  [unused3]  in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Art can find the lost Art can find the lost Art can find the lost.
# f2=  For Native American art in North America, see North American Native art .
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 3 chain =  [
#     {
#         "text": "Art can find the lost Art can find the lost Art can find the lost.",
#         "score": 20.327402
#     },
#     {
#         "text": "For Native American art in North America, see North American Native art .",
#         "score": 28.341608
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "art"
#                 ],
#                 "txt2_candidates": [
#                     "art"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "lost"
#                 ],
#                 "txtc_candidates": [
#                     "lost"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [],
#                 "txtc_candidates": []
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_4",
#         "turk_label": {
#             "label": "fact1"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             " [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3]   [unused1]  can find the  [unused3] ",
#             "for native american  [unused1]  in north america see north american native  [unused1] ",
#             "the north star can be used to find your way if you  re  [unused3]  in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Cabins are cheap and service always willing to find what you'r looking for.
# f2=  Astronomers look for the bright stars that orbit dark partners in the same way.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 4 chain =  [
#     {
#         "text": "Cabins are cheap and service always willing to find what you'r looking for.",
#         "score": 22.258617
#     },
#     {
#         "text": "Astronomers look for the bright stars that orbit dark partners in the same way.",
#         "score": 21.428736
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [],
#                 "txtc_candidates": []
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "stars",
#                     "way"
#                 ],
#                 "txtc_candidates": [
#                     "star",
#                     "way"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_5",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "cabins are cheap and service al [unused2]  willing to find what your looking for",
#             "astronomers look for the bright  [unused1]  that orbit dark partners in the same  [unused2] ",
#             "the north  [unused1]  can be used to find your  [unused2]  if you  re lost in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Cabins are cheap and service always willing to find what you'r looking for.
# f2=  Runaways always follow the star north.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 5 chain =  [
#     {
#         "text": "Cabins are cheap and service always willing to find what you'r looking for.",
#         "score": 22.258617
#     },
#     {
#         "text": "Runaways always follow the star north.",
#         "score": 20.61514
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [],
#                 "txtc_candidates": []
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "the star north"
#                 ],
#                 "txtc_candidates": [
#                     "the north star"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_6",
#         "turk_label": {
#             "label": "?"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "cabins are cheap and service always willing to find what your looking for",
#             "runaways always follow  [unused0] ",
#             " [unused1]  can be used to find your way if you  re lost in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Many birds use the moon, sun, and stars to find their way.
# f2=  And the sun is lost behind the darkness of the world.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 6 chain =  [
#     {
#         "text": "Many birds use the moon, sun, and stars to find their way.",
#         "score": 19.325905
#     },
#     {
#         "text": "And the sun is lost behind the darkness of the world.",
#         "score": 23.04217
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "sun"
#                 ],
#                 "txt2_candidates": [
#                     "sun"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "stars",
#                     "way"
#                 ],
#                 "txtc_candidates": [
#                     "star",
#                     "way"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "the darkness"
#                 ],
#                 "txtc_candidates": [
#                     "the dark"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_7",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "many birds use the moon  [unused1]  and  [unused3]  to find their  [unused4] ",
#             "and the  [unused1]  is lost behind  [unused5]  of the world",
#             "the north  [unused3]  can be used to find your  [unused4]  if you  re lost in  [unused5] "
#         ]
#     }
# ]
# ========================
# f1=  Many birds use the moon, sun, and stars to find their way.
# f2=  For a few days the moon is lost in the brilliance of the sun.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 7 chain =  [
#     {
#         "text": "Many birds use the moon, sun, and stars to find their way.",
#         "score": 19.325905
#     },
#     {
#         "text": "For a few days the moon is lost in the brilliance of the sun.",
#         "score": 22.75493
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "the moon",
#                     "sun"
#                 ],
#                 "txt2_candidates": [
#                     "the moon",
#                     "sun"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "stars",
#                     "way"
#                 ],
#                 "txtc_candidates": [
#                     "star",
#                     "way"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [],
#                 "txtc_candidates": []
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_8",
#         "turk_label": {
#             "label": "?"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "many birds use  [unused2]   [unused3]  and  [unused5]  to find their  [unused6] ",
#             "for a few days  [unused2]  is lost in the brilliance of the  [unused3] ",
#             "the north  [unused5]  can be used to find your  [unused6]  if you  re lost in the dark"
#         ]
#     }
# ]
# ========================
# f1=  Cabins are cheap and service always willing to find what you'r looking for.
# f2=  Stars always look prettier visually.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 8 chain =  [
#     {
#         "text": "Cabins are cheap and service always willing to find what you'r looking for.",
#         "score": 22.258617
#     },
#     {
#         "text": "Stars always look prettier visually.",
#         "score": 19.688793
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [],
#                 "txtc_candidates": []
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "stars"
#                 ],
#                 "txtc_candidates": [
#                     "star"
#                 ]
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_9",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "cabins are cheap and service always willing to find what your looking for",
#             " [unused0]  always look prettier visually",
#             "the north  [unused0]  can be used to find your way if you  re lost in the dark"
#         ]
#     }
# ]
# ========================
# f1=  By the way you'r taxi's minted.
# f2=  For trains on north- side lines, use taxi or subway to North Station.
# df=  the north star can be used to find your way if you ' re lost in the dark
#  ---->>> j= 9 chain =  [
#     {
#         "text": "By the way you'r taxi's minted.",
#         "score": 22.773825
#     },
#     {
#         "text": "For trains on north- side lines, use taxi or subway to North Station.",
#         "score": 18.468113
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "taxis"
#                 ],
#                 "txt2_candidates": [
#                     "taxi"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "way"
#                 ],
#                 "txtc_candidates": [
#                     "way"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [],
#                 "txtc_candidates": []
#             }
#         },
#         "chain_id": "3X4JMASXCM8FCX94IM0KEMYGMLZ0BD_1_10",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "the north star can be used to find your way if you ' re lost in the dark",
#         "grc": [
#             "by the  [unused2]  your  [unused0]  minted",
#             "for trains on north side lines use  [unused0]  or sub [unused2]  to north station",
#             "the north star can be used to find your  [unused2]  if you  re lost in the dark"
#         ]
#     }
# ]

# %%
show_random_example(data, show_correct_choice_only=True)
# Out:
# ==== ques =  what are therapsids?
# --------------------------------------------
# ==== option =  animals
# ========================
# f1=  Therapsids are reptiles ancestral to mammals.
# f2=  Animals can be classified into mammals, reptiles, birds.
# df=  animals are therapsids
#  ---->>> j= 0 chain =  [
#     {
#         "text": "Therapsids are reptiles ancestral to mammals.",
#         "score": 17.322662
#     },
#     {
#         "text": "Animals can be classified into mammals, reptiles, birds.",
#         "score": 24.840178
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_1",
#         "turk_label": {
#             "label": "yes"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             " [unused3]  are reptiles ancestral to  [unused1] ",
#             " [unused5]  can be classified into  [unused1]  reptiles birds",
#             " [unused5]  are  [unused3] "
#         ]
#     }
# ]
# ========================
# f1=  Therapsids are reptiles ancestral to mammals.
# f2=  Animals with a backbone are the Fishes, Amphibians, Reptiles, Birds, and Mammals .
# df=  animals are therapsids
#  ---->>> j= 1 chain =  [
#     {
#         "text": "Therapsids are reptiles ancestral to mammals.",
#         "score": 17.322662
#     },
#     {
#         "text": "Animals with a backbone are the Fishes, Amphibians, Reptiles, Birds, and Mammals .",
#         "score": 23.471836
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_2",
#         "turk_label": {
#             "label": "yes"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             " [unused3]  are reptiles ancestral to  [unused1] ",
#             " [unused5]  with a backbone are the fishes amphibians reptiles birds and  [unused1] ",
#             " [unused5]  are  [unused3] "
#         ]
#     }
# ]
# ========================
# f1=  Therapsids are reptiles ancestral to mammals.
# f2=  Animals Desert animals include insects, spiders, birds, reptiles, and mammals.
# df=  animals are therapsids
#  ---->>> j= 2 chain =  [
#     {
#         "text": "Therapsids are reptiles ancestral to mammals.",
#         "score": 17.322662
#     },
#     {
#         "text": "Animals Desert animals include insects, spiders, birds, reptiles, and mammals.",
#         "score": 23.212591
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_3",
#         "turk_label": {
#             "label": "yes"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             " [unused3]  are reptiles ancestral to  [unused1] ",
#             " [unused5]  desert  [unused5]  include insects spiders birds reptiles and  [unused1] ",
#             " [unused5]  are  [unused3] "
#         ]
#     }
# ]
# ========================
# f1=  Tetraceratops is the oldest known therapsid.
# f2=  Invertebrates are the oldest known animals on earth.
# df=  animals are therapsids
#  ---->>> j= 3 chain =  [
#     {
#         "text": "Tetraceratops is the oldest known therapsid.",
#         "score": 17.322662
#     },
#     {
#         "text": "Invertebrates are the oldest known animals on earth.",
#         "score": 22.84494
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsid"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_4",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             "tetraceratops is the oldest known  [unused0] ",
#             "invertebrates are the oldest known  [unused2]  on earth",
#             " [unused2]  are  [unused0] "
#         ]
#     }
# ]
# ========================
# f1=  Therapsids are reptiles ancestral to mammals.
# f2=  Among the animal destroyers are varieties of freshwater fish, reptiles and mammals.
# df=  animals are therapsids
#  ---->>> j= 4 chain =  [
#     {
#         "text": "Therapsids are reptiles ancestral to mammals.",
#         "score": 17.322662
#     },
#     {
#         "text": "Among the animal destroyers are varieties of freshwater fish, reptiles and mammals.",
#         "score": 22.246372
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animal"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_5",
#         "turk_label": {
#             "label": "?"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             " [unused3]  are reptiles ancestral to  [unused1] ",
#             "among the  [unused4]  destroyers are varieties of freshwater fish reptiles and  [unused1] ",
#             " [unused4]  are  [unused3] "
#         ]
#     }
# ]
# ========================
# f1=  Tetraceratops is the oldest known therapsid.
# f2=  Bantams are among the oldest known domestic animals.
# df=  animals are therapsids
#  ---->>> j= 5 chain =  [
#     {
#         "text": "Tetraceratops is the oldest known therapsid.",
#         "score": 17.322662
#     },
#     {
#         "text": "Bantams are among the oldest known domestic animals.",
#         "score": 21.513144
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsid"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_6",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             "tetraceratops is the oldest known  [unused0] ",
#             "bantams are among the oldest known domestic  [unused2] ",
#             " [unused2]  are  [unused0] "
#         ]
#     }
# ]
# ========================
# f1=  Pelycosaurs and therapsids are theropsids.
# f2=  Some pelycosaurs gave rise to a group of animals called therapsids.
# df=  animals are therapsids
#  ---->>> j= 6 chain =  [
#     {
#         "text": "Pelycosaurs and therapsids are theropsids.",
#         "score": 18.546577
#     },
#     {
#         "text": "Some pelycosaurs gave rise to a group of animals called therapsids.",
#         "score": 19.248562
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "pelycosaurs",
#                     "therapsids"
#                 ],
#                 "txt2_candidates": [
#                     "pelycosaurs",
#                     "therapsids"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals",
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "animals",
#                     "therapsids"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_7",
#         "turk_label": {
#             "label": "yes"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             " [unused2]  and  [unused9]  are theropsids",
#             "some  [unused2]  gave rise to a group of  [unused8]  called  [unused9] ",
#             " [unused8]  are  [unused9] "
#         ]
#     }
# ]
# ========================
# f1=  Tetraceratops is the oldest known therapsid.
# f2=  Angora goat is one of the oldest animals known to man.
# df=  animals are therapsids
#  ---->>> j= 7 chain =  [
#     {
#         "text": "Tetraceratops is the oldest known therapsid.",
#         "score": 17.322662
#     },
#     {
#         "text": "Angora goat is one of the oldest animals known to man.",
#         "score": 20.328072
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [],
#                 "txt2_candidates": []
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsid"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_8",
#         "turk_label": {
#             "label": "no"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             "tetraceratops is the oldest known  [unused0] ",
#             "angora goat is one of the oldest  [unused2]  known to man",
#             " [unused2]  are  [unused0] "
#         ]
#     }
# ]
# ========================
# f1=  Pelycosaurs, mammals, and the morphologically intermediate therapsids form Synapsida .
# f2=  Mammals are the highest form of animal life.
# df=  animals are therapsids
#  ---->>> j= 8 chain =  [
#     {
#         "text": "Pelycosaurs, mammals, and the morphologically intermediate therapsids form Synapsida .",
#         "score": 14.459958
#     },
#     {
#         "text": "Mammals are the highest form of animal life.",
#         "score": 21.166033
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "form",
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "form",
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [],
#                 "txtc_candidates": []
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_9",
#         "turk_label": {
#             "label": "?"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             "pelycosaurs  [unused3]  and the morphologically intermediate  [unused5]   [unused2]  synapsida",
#             " [unused3]  are the highest  [unused2]  of animal life",
#             "animals are  [unused5] "
#         ]
#     }
# ]
# ========================
# f1=  Cynodonts are the therapsids from which mammals evolved.
# f2=  Since whales are mammals, evolution predicts that they evolved from land animals.
# df=  animals are therapsids
#  ---->>> j= 9 chain =  [
#     {
#         "text": "Cynodonts are the therapsids from which mammals evolved.",
#         "score": 15.302935
#     },
#     {
#         "text": "Since whales are mammals, evolution predicts that they evolved from land animals.",
#         "score": 19.930908
#     },
#     {
#         "overlapping_entities": {
#             "txt12_candidates": {
#                 "txt1_candidates": [
#                     "mammals"
#                 ],
#                 "txt2_candidates": [
#                     "mammals"
#                 ]
#             },
#             "txt1c_candidates": {
#                 "txt1_candidates": [
#                     "therapsids"
#                 ],
#                 "txtc_candidates": [
#                     "therapsids"
#                 ]
#             },
#             "txt2c_candidates": {
#                 "txt2_candidates": [
#                     "animals"
#                 ],
#                 "txtc_candidates": [
#                     "animals"
#                 ]
#             }
#         },
#         "chain_id": "3V5Q80FXIXQH5C85IGPSFRTJXGV32E_1_10",
#         "turk_label": {
#             "label": "yes"
#         },
#         "df": "animals are therapsids",
#         "grc": [
#             "cynodonts are the  [unused3]  from which  [unused1]  evolved",
#             "since whales are  [unused1]  evolution predicts that they evolved from land  [unused5] ",
#             " [unused5]  are  [unused3] "
#         ]
#     }
# ]

# %%
###############

# %%
# it might be easier to read some of the grc chains by using alphabet variables instead of '[unusedi]' tokens

def utility_to_replace_unused_with_vars(grc_chain, vars_to_use = ['X','Y','Z','U','V','W']):
    assert len(grc_chain) == 3
    mapper = {}
    idx = 0
    ret = []
    for row in grc_chain:
        t = []
        tokens = row.strip().split()
        for token in tokens:
            if token.startswith('[unused'):
                if token not in mapper:
                    mapper[token] = vars_to_use[idx]
                    idx += 1
                t.append(mapper[token])
            else:
                t.append(token)
        ret.append(' '.join(t))
    return ret

# %%
grc = [
            " [unused2]  and  [unused9]  are theropsids",
            "some  [unused2]  gave rise to a group of  [unused8]  called  [unused9] ",
            " [unused8]  are  [unused9] "
        ]
# a valid reasoning chain

# %%
utility_to_replace_unused_with_vars(grc)
# Out:
# ['X and Y are theropsids',
#  'some X gave rise to a group of Z called Y',
#  'Z are Y']

# %%
grc = [" [unused3]  are reptiles ancestral to  [unused1] ",
            " [unused5]  can be classified into  [unused1]  reptiles birds",
            " [unused5]  are  [unused3] "]
# a valid reasoning chain
# 'reptiles' got wrong POS

# %%
utility_to_replace_unused_with_vars(grc)
# Out:
# ['X are reptiles ancestral to Y',
#  'Z can be classified into Y reptiles birds',
#  'Z are X']

# %%
grc = [ "tetraceratops is the oldest known  [unused0] ",
         "bantams are among the oldest known domestic  [unused2] ",
         " [unused2]  are  [unused0] " ]
# an invalid reasoning chain

# %%
utility_to_replace_unused_with_vars(grc)
# Out:
# ['tetraceratops is the oldest known X',
#  'bantams are among the oldest known domestic Y',
#  'Y are X']

# %%
############### Inspecting eqasc-perturbed

# %%
fname = 'eqasc_perturbed/turk_modified_test.tsv'
# QID	Fact1	Fact2	Combined	Fact1Edited	Fact2Edited	CombinedEdited	Fact1Change	Fact2Change	CombinedChange

# %%
data = open(fname,'r').readlines()
data = [row.strip().split('\t') for row in data]
headers,data = data[0],data[1:]

# %%
headers
# Out:
# ['QID',
#  'Fact1',
#  'Fact2',
#  'Combined',
#  'Fact1Edited',
#  'Fact2Edited',
#  'CombinedEdited',
#  'Fact1Change',
#  'Fact2Change',
#  'CombinedChange']

# %%
data[0]
# Out:
# ['3018Q3ZVOIPYTHOB6LJ337FXF57ARA',
#  'Bryophytes occupy niches in moist habitats.',
#  'Mosses and liverworts are bryophytes.',
#  'mosses occupy niches in moist habitats',
#  'Bryophytes occupy homes in moist habitats.',
#  'Mosses and liverworts are bryophytes.',
#  'mosses occupy homes in moist habitats',
#  'niche -> "home"',
#  'NIL -> NIL',
#  'niche -> "home"']

# %%
def see_random_example_eqasc_pert(data):
    row = random.choice(data)
    idx, original, edited, edits = row[0], row[1:4], row[4:7], row[7:10]
    print("idx=",idx)
    print("original=",original)
    print("edited=",edited)
    print("edits=",edits)

# %%
random.seed(123)

# %%
see_random_example_eqasc_pert(data)
# Out:
# idx= 320DUZ38G7LI5KI1KG24X24923MGJZ
# original= ['a radio is used for communication', 'Internal communication is very important during any emergency situation.', 'radios are very important during any emergency situation']
# edited= ['a radio is used for conversation', 'Internal conversation is very important during any emergency situation.', 'radios are very important during any emergency situation']
# edits= ['communication -> "conversation"', 'communication -> "conversation"', 'NIL -> NIL']

# %%
see_random_example_eqasc_pert(data)
# Out:
# idx= 3CFVK00FWLKM3HHVBO5V1Q4CE4GL6E
# original= ['Most bryophytes are small.', 'Bryophytes include the mosses and liverworts.', 'most mosses are small']
# edited= ['Most bryophytes are microscopic.', 'Bryophytes include the mosses and liverworts.', 'most mosses are microscopic.']
# edits= ['small -> "microscopic"', 'NIL -> NIL', 'small -> "microscopic"']

# %%
see_random_example_eqasc_pert(data)
# Out:
# idx= 33FBRBDW6OYG4R6DRQ9UILAGTOVC8D
# original= ['Bladder infections can be treated with antibiotics prescribed by a doctor.', 'If it is viral, no antibiotics are indicated.', 'bladder infections are not viral in nature']
# edited= ['Bladder infections can be treated with medicines prescribed by a doctor.', 'If it is viral, no medicines are indicated.', 'bladder infections are not viral in nature']
# edits= ['antibiotic -> "medicine"', 'antibiotic -> "medicine"', 'NIL -> NIL']
